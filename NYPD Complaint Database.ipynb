# %%
# read in database and analyze data structure, recent as of April 20, 2021
import pandas as pd
df = pd.read_csv('CCRB Complaint Database Raw 04.20.2021.csv')
# first 5 rows
df.head(5)
# Out:
# /tmp/ipykernel_30500/3586126766.py:3: DtypeWarning: Columns (10,11,12,18,23,24,25,26,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CCRB Complaint Database Raw 04.20.2021.csv')
#     AsOfDate  AllegationID  LastName FirstName OfficerRace OfficerGender  \
# 0  4/20/2021       1119144  Ruscillo    Taylor       White        Female
# 1  4/20/2021       1116090    Medina    Nelson    Hispanic          Male
# 2  4/20/2021       1116091    Pierre    Bebeto       Black          Male
# 3  4/20/2021       1115473   Chapman      John       White          Male
# 4  4/20/2021       1115475    Tafuro    Justin       White          Male
#
#    OfficerID CurrentRank CurrentRankLong CurrentCommand  ... PenaltyDesc  \
# 0      54191         POF  Police Officer        MTN PCT  ...         NaN
# 1      76926         POM  Police Officer        TB DT02  ...         NaN
# ...

# %%
import matplotlib.pyplot as plt
 
# create the data for the graph
data = df['OfficerRace'].value_counts()
# 2020 Census data in NY
# https://www.census.gov/library/stories/state-by-state/new-york-population-change-between-census-decade.html
percentages = {
    'White alone' : 61.6,
    'Black alone' : 12.4,
    'Hispanic' : 18.7,
    'Asian alone' : 6,
    'American Indian and Alaska Native alone' : 1.1,
    'Native Hawaiian and Other Pacific Islander alone' : 0.2
    #'Two or More Races' :  10.2
}
data_census = pd.Series(percentages)
# plot the data
plt.rcParams['figure.figsize'] = [7, 7]
plt.pie(data_census, labels=data_census.index, autopct='%1.1f%%')
plt.title('2020 NY Census Race Distribution')
plt.show()
# plot the data
plt.pie(data, labels=data.index, autopct='%1.1f%%')
plt.title('2021 NYPD Complaint Misconduct Race Distribution')
plt.show()
